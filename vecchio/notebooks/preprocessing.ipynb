# %% [markdown]
# # PROBABILE STRUTTURA
# 1. Caricamento dei file audio
# 2. Parsing del filename → estrazione emotion_id
# 3. Creazione DataFrame per vedere se tutto è corretto  ← QUI metti il codice
# 4. Generazione dei mel-spectrogram
# 5. Decisione dei parametri (n_mels, hop, win, durata, padding)
# 6. Test di un paio di augmentations

# %%
#!pip install pandas

# %%
import os
os.getcwd()
import sys
sys.path.append("../src")

import pandas as pd
from glob import glob
from preprocessing.dataset import extract_emotion_label, EMOTION_MAP

audio_files = glob("../data/Actor_*/*.wav", recursive=True)
print("Numero totale file:", len(audio_files))
audio_files[:3]

rows = []

for f in audio_files:
    filename = os.path.basename(f)
    parts = filename.split('-')

    emotion_id = parts[2]
    emotion_label = EMOTION_MAP[emotion_id]

    actor = parts[-1].split('.')[0]  # ultimo numero prima del .wav

    rows.append([f, emotion_id, emotion_label, actor])

df = pd.DataFrame(rows, columns=["filepath", "emotion_id", "emotion_label", "actor"])
df.head()
# Out:
# Numero totale file: 1440
#                                     filepath emotion_id emotion_label actor
# 0  ../data\Actor_01\03-01-01-01-01-01-01.wav         01       neutral    01
# 1  ../data\Actor_01\03-01-01-01-01-02-01.wav         01       neutral    01
# 2  ../data\Actor_01\03-01-01-01-02-01-01.wav         01       neutral    01
# 3  ../data\Actor_01\03-01-01-01-02-02-01.wav         01       neutral    01
# 4  ../data\Actor_01\03-01-02-01-01-01-01.wav         02          calm    01

# %%
# Verifica della corretta popolazione del dataset

print("=== DATASET CHECK ===\n")

print(f"Totale file audio: {len(df)}\n")

print("Distribuzione emozioni:")
print(df["emotion_label"].value_counts().sort_index(), "\n")

print("Distribuzione attori:")
print(df["actor"].value_counts().sort_index(), "\n")
# Out:
# === DATASET CHECK ===
#
# Totale file audio: 1440
#
# Distribuzione emozioni:
# emotion_label
# angry        192
# calm         192
# disgust      192
# fearful      192
# happy        192
# neutral       96
# sad          192
# surprised    192
# Name: count, dtype: int64
#
# Distribuzione attori:
# actor
# 01    60
# 02    60
# 03    60
# 04    60
# 05    60
# 06    60
# 07    60
# 08    60
# 09    60
# 10    60
# 11    60
# 12    60
# 13    60
# 14    60
# 15    60
# 16    60
# 17    60
# 18    60
# 19    60
# 20    60
# 21    60
# 22    60
# 23    60
# 24    60
# Name: count, dtype: int64

# %%
import os
os.getcwd()
import sys
sys.path.append("../src")

# %%
from torch.utils.data import DataLoader
from preprocessing.dataset import list_ravdess_files, split_by_speakers, RavdessDataset, plot_log_mel_from_loader, filter_audio_speech

all_files = list_ravdess_files("../data")
all_files = filter_audio_speech(all_files)

train_spk = [f"{i:02d}" for i in range(1, 19)]   # 01..18
val_spk   = [f"{i:02d}" for i in range(19, 23)]  # 19..22
test_spk  = [f"{i:02d}" for i in range(23, 25)]  # 23..24

train_files, val_files, test_files = split_by_speakers(all_files, train_spk, val_spk, test_spk)

train_ds = RavdessDataset(train_files)
train_loader = DataLoader(train_ds, batch_size=16, shuffle=True)

X, y = next(iter(train_loader))
print(X.shape, y.shape)  # atteso: [B, 1, 64, 401]  e [B]

plot_log_mel_from_loader(train_loader)
# Out:
# torch.Size([16, 1, 128, 126]) torch.Size([16])

# %%
import torch
from models.crnn import CRNNBaseline

X, y = next(iter(train_loader))  # X: [B, 1, 64, 401]
model = CRNNBaseline(num_classes=8)

logits = model(X)
print("logits shape:", logits.shape)  # atteso: [B, 8]
# Out:
# logits shape: torch.Size([16, 8])

# %%
import torch
from models.crnn import CRNNBaseline
from training.train import train_model

device = "cuda" if torch.cuda.is_available() else "cpu"

model = CRNNBaseline(num_classes=8)

from torch.utils.data import DataLoader
from preprocessing.dataset import RavdessDataset

# Dataset
train_ds = RavdessDataset(train_files, augmentation=True)
val_ds   = RavdessDataset(val_files)
test_ds  = RavdessDataset(test_files)

# DataLoader
train_loader = DataLoader(train_ds, batch_size=64, shuffle=True)
val_loader   = DataLoader(val_ds, batch_size=64, shuffle=False)
test_loader  = DataLoader(test_ds, batch_size=64, shuffle=False)


history = train_model(
    model=model,
    train_loader=train_loader,
    val_loader=val_loader,
    epochs=100,
    lr=3e-4,
    device=device,
    save_dir="checkpoints",
    save_name="crnn_baseline_best.pt"
)
# Out:
# Epoch 01/100 | train loss 2.0608 acc 0.1528 | val loss 2.0470 acc 0.1833
#   -> saved best model to: checkpoints\crnn_baseline_best.pt
# Epoch 02/100 | train loss 2.0199 acc 0.2444 | val loss 2.0075 acc 0.2000
#   -> saved best model to: checkpoints\crnn_baseline_best.pt
# Epoch 03/100 | train loss 1.9812 acc 0.2481 | val loss 1.9986 acc 0.1750
#   -> saved best model to: checkpoints\crnn_baseline_best.pt
# Epoch 04/100 | train loss 1.9406 acc 0.2491 | val loss 1.9779 acc 0.1958
#   -> saved best model to: checkpoints\crnn_baseline_best.pt
# Epoch 05/100 | train loss 1.9041 acc 0.2519 | val loss 1.9629 acc 0.2208
#   -> saved best model to: checkpoints\crnn_baseline_best.pt
# Epoch 06/100 | train loss 1.8622 acc 0.2796 | val loss 1.9243 acc 0.2583
#   -> saved best model to: checkpoints\crnn_baseline_best.pt
# Epoch 07/100 | train loss 1.8520 acc 0.2667 | val loss 1.9741 acc 0.2250
# Epoch 08/100 | train loss 1.8292 acc 0.2926 | val loss 2.0038 acc 0.2167
# Epoch 09/100 | train loss 1.8217 acc 0.2685 | val loss 1.9912 acc 0.2333
# Epoch 10/100 | train loss 1.8054 acc 0.2963 | val loss 1.9629 acc 0.2458
# Epoch 11/100 | train loss 1.7969 acc 0.2880 | val loss 1.9699 acc 0.2292
# Epoch 12/100 | train loss 1.7857 acc 0.2991 | val loss 1.9784 acc 0.2417
# Epoch 13/100 | train loss 1.7784 acc 0.2833 | val loss 1.9162 acc 0.2667
#   -> saved best model to: checkpoints\crnn_baseline_best.pt
# Epoch 14/100 | train loss 1.7749 acc 0.3204 | val loss 1.9110 acc 0.2667
#   -> saved best model to: checkpoints\crnn_baseline_best.pt
# Epoch 15/100 | train loss 1.7570 acc 0.3130 | val loss 1.9137 acc 0.2625
# Epoch 16/100 | train loss 1.7566 acc 0.3185 | val loss 1.8949 acc 0.2667
#   -> saved best model to: checkpoints\crnn_baseline_best.pt
# Epoch 17/100 | train loss 1.7388 acc 0.3269 | val loss 1.8913 acc 0.2625
#   -> saved best model to: checkpoints\crnn_baseline_best.pt
# Epoch 18/100 | train loss 1.7462 acc 0.3231 | val loss 1.8385 acc 0.2792
#   -> saved best model to: checkpoints\crnn_baseline_best.pt
# Epoch 19/100 | train loss 1.7221 acc 0.3361 | val loss 1.8199 acc 0.2875
#   -> saved best model to: checkpoints\crnn_baseline_best.pt
# Epoch 20/100 | train loss 1.7381 acc 0.3185 | val loss 1.8367 acc 0.2792
# Epoch 21/100 | train loss 1.6910 acc 0.3602 | val loss 1.7935 acc 0.3000
#   -> saved best model to: checkpoints\crnn_baseline_best.pt
# Epoch 22/100 | train loss 1.6996 acc 0.3546 | val loss 1.7973 acc 0.2917
# Epoch 23/100 | train loss 1.6832 acc 0.3500 | val loss 1.7662 acc 0.3125
#   -> saved best model to: checkpoints\crnn_baseline_best.pt
# Epoch 24/100 | train loss 1.6592 acc 0.3769 | val loss 1.7591 acc 0.3208
#   -> saved best model to: checkpoints\crnn_baseline_best.pt
# Epoch 25/100 | train loss 1.6418 acc 0.3769 | val loss 1.7290 acc 0.3208
#   -> saved best model to: checkpoints\crnn_baseline_best.pt
# Epoch 26/100 | train loss 1.6266 acc 0.3907 | val loss 1.7214 acc 0.3083
#   -> saved best model to: checkpoints\crnn_baseline_best.pt
# Epoch
#   -> saved best model to: checkpoints\crnn_baseline_best.pt
# Epoch 64/100 | train loss 1.0630 acc 0.6148 | val loss 1.4138 acc 0.4625
# Epoch 65/100 | train loss 1.0332 acc 0.6398 | val loss 1.3812 acc 0.5000
# Epoch 66/100 | train loss 1.0193 acc 0.6491 | val loss 1.4062 acc 0.4708
# Epoch 67/100 | train loss 1.0240 acc 0.6463 | val loss 1.4245 acc 0.4833
# Epoch 68/100 | train loss 1.0017 acc 0.6472 | val loss 1.3515 acc 0.4958
#   -> saved best model to: checkpoints\crnn_baseline_best.pt
# Epoch 69/100 | train loss 1.0044 acc 0.6481 | val loss 1.3863 acc 0.4792
# Epoch 70/100 | train loss 0.9820 acc 0.6583 | val loss 1.3549 acc 0.5042
# Epoch 71/100 | train loss 0.9466 acc 0.6694 | val loss 1.4048 acc 0.4875
# Epoch 72/100 | train loss 0.9665 acc 0.6722 | val loss 1.3207 acc 0.5000
#   -> saved best model to: checkpoints\crnn_baseline_best.pt
# Epoch 73/100 | train loss 0.9346 acc 0.6824 | val loss 1.3880 acc 0.4958
# Epoch 74/100 | train loss 0.9335 acc 0.6889 | val loss 1.3440 acc 0.5000
# Epoch 75/100 | train loss 0.9525 acc 0.6704 | val loss 1.3954 acc 0.4833
# Epoch 76/100 | train loss 0.9508 acc 0.6787 | val loss 1.3117 acc 0.5125
#   -> saved best model to: checkpoints\crnn_baseline_best.pt
# Epoch 77/100 | train loss 0.9180 acc 0.6870 | val loss 1.2786 acc 0.5375
#   -> saved best model to: checkpoints\crnn_baseline_best.pt
# Epoch 78/100 | train loss 0.8935 acc 0.7009 | val loss 1.3443 acc 0.5042
# Epoch 79/100 | train loss 0.8708 acc 0.7019 | val loss 1.2837 acc 0.5250
# Epoch 80/100 | train loss 0.8677 acc 0.7028 | val loss 1.3492 acc 0.5292
# Epoch 81/100 | train loss 0.8874 acc 0.6926 | val loss 1.3871 acc 0.4917
# Epoch 82/100 | train loss 0.8518 acc 0.7213 | val loss 1.2761 acc 0.5458
#   -> saved best model to: checkpoints\crnn_baseline_best.pt
# Epoch 83/100 | train loss 0.8938 acc 0.6954 | val loss 1.3038 acc 0.5292
# Epoch 84/100 | train loss 0.8467 acc 0.7231 | val loss 1.3535 acc 0.5167
# Epoch 85/100 | train loss 0.8273 acc 0.7361 | val loss 1.3399 acc 0.5250
# Epoch 86/100 | train loss 0.8096 acc 0.7315 | val loss 1.2842 acc 0.5333
# Epoch 87/100 | train loss 0.8097 acc 0.7333 | val loss 1.3658 acc 0.5250
# Epoch 88/100 | train loss 0.7860 acc 0.7407 | val loss 1.2310 acc 0.5542
#   -> saved best model to: checkpoints\crnn_baseline_best.pt
# Epoch 89/100 | train loss 0.8092 acc 0.7296 | val loss 1.2544 acc 0.5542
# Epoch 90/100 | train loss 0.8135 acc 0.7148 | val loss 1.4192 acc 0.5042
# Epoch 91/100 | train loss 0.7702 acc 0.7343 | val loss 1.2457 acc 0.5375
# Epoch 92/100 | train loss 0.7867 acc 0.7491 | val loss 1.2963 acc 0.5583
# Epoch 93/100 | train loss 0.7709 acc 0.7417 | val loss 1.2862 acc 0.5375
# Epoch 94/100 | train loss 0.7405 acc 0.7509 | val loss 1.3376 acc 0.5417
# Epoch 95/100 | train loss 0.7316 acc 0.7639 | val loss 1.3384 acc 0.5333
# Epoch 96/100 | train loss 0.7022 acc 0.7935 | val loss 1.2492 acc 0.5458
# Epoch 97/100 | train loss 0.7258 acc 0.7583 | val loss 1.3119 acc 0.5542
# Epoch 98/100 | train loss 0.7255 acc 0.7630 | val loss 1.3703 acc 0.5375
# Epoch 99/100 | train loss 0.6870 acc 0.7731 | val loss 1.2780 acc 0.5417
# Epoch 100/100 | train loss 0.7051 acc 0.7731 | val loss 1.2852 acc 0.5542

# %%
import torch
from models.crnn import CRNNBaseline
from evaluation.metrics import evaluate_model

device = "cuda" if torch.cuda.is_available() else "cpu"

# 1) ricrea modello
model = CRNNBaseline(num_classes=8).to(device)

# 2) carica best checkpoint
ckpt = torch.load("checkpoints/crnn_baseline_best.pt", map_location=device)
model.load_state_dict(ckpt["model_state_dict"])

# 3) eval
acc, precision, recall, f1, cm, report = evaluate_model(model, test_loader, device=device)

print("TEST RESULTS")
print(f"Accuracy:  {acc:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall:    {recall:.4f}")
print(f"F1-score:  {f1:.4f}")

print("\nClassification report:\n")
print(report)

print("Confusion Matrix:\n", cm)
# Out:
# TEST RESULTS
# Accuracy:  0.5083
# Precision: 0.5250
# Recall:    0.4922
# F1-score:  0.4649
#
# Classification report:
#
#               precision    recall  f1-score   support
#
#            0       0.50      0.25      0.33         8
#            1       0.54      0.44      0.48        16
#            2       0.40      0.12      0.19        16
#            3       0.31      0.31      0.31        16
#            4       0.83      0.31      0.45        16
#            5       0.45      0.81      0.58        16
#            6       0.63      0.75      0.69        16
#            7       0.54      0.94      0.68        16
#
#     accuracy                           0.51       120
#    macro avg       0.52      0.49      0.46       120
# weighted avg       0.53      0.51      0.47       120
#
# Confusion Matrix:
#  [[ 2  0  0  5  0  1  0  0]
#  [ 2  7  0  2  0  5  0  0]
#  [ 0  1  2  3  0  2  1  7]
#  [ 0  5  0  5  0  4  2  0]
#  [ 0  0  2  0  5  3  1  5]
#  [ 0  0  0  0  0 13  2  1]
#  [ 0  0  1  1  1  1 12  0]
#  [ 0  0  0  0  0  0  1 15]]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(7, 6))
plt.imshow(cm, aspect="auto", origin="upper")
plt.colorbar()
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.tight_layout()
plt.show()

# %%
# PLOT DELLE CURVE DI ACCURACY E LOSS

import matplotlib.pyplot as plt

def plot_history(history):
    epochs = range(1, len(history["train_loss"]) + 1)

    # Loss
    plt.figure()
    plt.plot(epochs, history["train_loss"], label="train_loss")
    plt.plot(epochs, history["val_loss"], label="val_loss")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.title("Loss curve")
    plt.legend()
    plt.show()

    # Accuracy
    plt.figure()
    plt.plot(epochs, history["train_acc"], label="train_acc")
    plt.plot(epochs, history["val_acc"], label="val_acc")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    plt.title("Accuracy curve")
    plt.legend()
    plt.show()

plot_history(history)

# %%
# PARAMETRI USATI
def print_training_summary(model, optimizer, train_loader, history):
    # Batch size
    batch_size = train_loader.batch_size

    # Numero epoche effettive (da history)
    epochs_done = len(history["train_loss"])

    # Optimizer name + LR
    optim_name = optimizer.__class__.__name__
    lr = optimizer.param_groups[0]["lr"]

    # Parametri modello (quanti pesi)
    total_params = sum(p.numel() for p in model.parameters())
    trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)

    print("\n================ TRAINING SUMMARY ================")
    print(f"Batch size:        {batch_size}")
    print(f"Epochs:            {epochs_done}")
    print(f"Optimizer:         {optim_name}")
    print(f"Learning rate:     {lr}")
    print(f"Total params:      {total_params}")
    print(f"Trainable params:  {trainable_params}")
    print("==================================================\n")


import torch.nn as nn
import torch

optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
criterion = nn.CrossEntropyLoss()

print_training_summary(model, optimizer, train_loader, history)
# Out:
# ================ TRAINING SUMMARY ================
# Batch size:        64
# Epochs:            100
# Optimizer:         Adam
# Learning rate:     0.001
# Total params:      657096
# Trainable params:  657096
# ==================================================
